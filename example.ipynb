# %%
# %matplotlib widget

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import crixs.models.stepfunctions as myfunc

# %%
plt.figure()
x = np.linspace(-6,6,1000)
y = myfunc.error_func(x,1.,0,0.5)
plt.plot(x,y)

y = myfunc.sigmoid_func(x,1.,0,0.5)
plt.plot(x,y)


y = myfunc.arctan_func(x,1.,0,0.5*np.sqrt(2/np.pi))
plt.plot(x,y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
x = np.linspace(-3,3,1000)
y = myfunc.error_fwhm(x,1.,0,0.5)
plt.plot(x,y)

x = np.linspace(-3,3,1000)
y = myfunc.sigmoid_fwhm(x,1.,0,0.5)
plt.plot(x,y)

x = np.linspace(-3,3,1000)
y = myfunc.arctan_fwhm(x,1.,0,0.5)
plt.plot(x,y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.log(3 + 2 * np.sqrt(2))
# Out:
# 1.762747174039086

# %%
(2 * np.sqrt(2 * np.log(2)))
# Out:
# 2.3548200450309493
