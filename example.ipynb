# %%
# %matplotlib widget

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import crixs.models.stepfunctions as myfunc

# %%
from crixs.Spectrum import Spectrum as spc

# %%
a = spc(x=[0,0.5,1],y=[0,0.5,1])
b = spc(x=[0,0.5,1],y=[0,0.5,1])

# %%
b.x is a.x
# Out:
# False

# %%
b.x = a.x
b.x is a.x
# Out:
# False

# %%
a = np.array(1)

# %%
from crixs.Fitting import *

# %%
import numpy as np

def func1(x, a):
    return a * x
def func2(x, b):
    return b* np.cos(x)

ft = Fitting()

ft.modeling(func2, prefix="i_")
ft.modeling(func1, prefix="s_")

# Params_init = {
#     "gb": {"value": 0},
# }

# ft.init(Params_init)

x = np.linspace(-1, 1, 100)
y = np.cos(x*10)
ss = Spectrum(x, y)

ft.fit(ss)

result = ft.result

line = ft.out('s_')
# Out:
# True
# c:\Researches\Scripts\CRIXS\crixs\Spectrum.py:82: RuntimeWarning: invalid value encountered in sqrt
#   self._err = np.sqrt(self._y)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(ss.x,ss.y)
line = ft.out()
plt.plot(line.x,line.y)


line = ft.out('s_')
plt.plot(line.x,line.y)
line = ft.out('i_')
plt.plot(line.x,line.y)
# Out:
# True
# True

# %%
print(result)
# Out:
# {'i_b': {'value': -0.03699299372352294, 'stderr': 0.08646297790500354}, 's_a': {'value': -2.4524826613969708e-12, 'stderr': 0.05230273095944579}}

# %%
ft.model
# Out:
# <lmfit.Model: (Model(func2, prefix='i_') + Model(func1, prefix='s_'))>
